# %% [markdown]
# # استاد مهربان

# %% [markdown]
# در این تمرین می‌خواهیم مقدمات کار با با این کتاب‌خانه را با هم تمرین کنیم.

# %% [markdown]
# آرایه زیر را که نمرات صد دانشجوی مختلف در درس ریاضی یک دانشگاه شریف است، در نظر بگیرید(داده‌ها واقعی نیستند):

# %%
import numpy as np

# %%
grades = np.array([ 3. , 17. ,  6.5,  0.5,  8. ,  6.5, 19. , 13.5,  2.5, 17. , 19. ,
       19.5, 13. ,  0. ,  6. ,  0.5,  9.5, 13.5, 16. ,  2.5, 10.5,  8. ,
       10. , 15.5,  7.5,  0. ,  1. , 10.5,  2. , 11. ,  3. , 14. ,  3.5,
       18.5, 13. ,  1. , 14.5, 15. ,  1. , 15.5,  1.5,  2. ,  3.5,  6.5,
        2.5, 14.5, 11.5,  8. ,  0. ,  5.5,  0.5, 20. ,  5. ,  0.5, 17.5,
       17.5, 17.5, 15. ,  4.5, 17. , 18. , 10. ,  8.5, 14. , 18.5, 19.5,
       16. ,  8.5,  0. ,  9.5,  6. ,  2. ,  5. ,  9.5,  4. ,  4. ,  1. ,
        8. , 18.5, 18. , 15.5,  4.5,  1.5, 20. ,  0.5, 19. ,  4. ,  9.5,
       13. , 10. ,  3.5,  1.5,  6.5,  0.5, 11.5, 17. , 13.5, 11.5, 13. ,
       13. ])

# %% [markdown]
# بعد از ثبت نمرات، استاد درس تصمیم می‌گیرد که به دانشجویان درس ارفاقی انجام دهد. به این صورت که(x نمره اصلی و y نمره با ارفاق شخص است.):
#
# ۱. اگر نمره شخص کمتر از هفت است:
#
# $ y = 9 + \frac{x}{10} $
#
# ۲. اگر نمره او بیشتر یا مساوی هفت است:
#
# $ y =  -0.0047x^{2} + 0.9571x + 3.5333 $
#
# توجه کنید که بیشینه نمره بیست است. بنابراین اگر نمره‌ای بیشتر از بیست شود، همان بیست منظور می‌شود.
#
# (فرمول بالا برگرفته از فرمول به کار رفته برای درس ریاضی یک دانشگاه شریف در سال ۹۷ است.)
#
# نمرات جدید را حساب کنید و در همان آرایه نمرات ذخیره کنید.
#
# (راهنمایی: توجه کنید که نمره جدید همه اشخاصی که نمره اصلی‌شان کمتر از هفت بوده، از همه اشخاصی که نمره اصلی‌شان بیشتر از هفت بوده کمتر می‌شود. )

# %%
grades[grades<7] = 9+grades[grades<7]/10
print(grades)
grades[grades>=7] = -0.0047*(grades[grades>=7]**2) + 0.9571*grades[grades>=7] + 3.5333
grades[grades>20] = 20
# Out:
# [14.3651907  19.58853338 14.62118609 14.18120915 13.39813781 14.62118609
#  20.         17.31830261 14.32846972 19.58853338 20.         20.
#  16.98010444 14.1442997  14.58472777 14.18120915 14.5116988  17.31830261
#  18.95697457 14.32846972 15.2352775  13.39813781 14.87534851 18.63612537
#  13.0193169  14.1442997  14.21808085 15.2352775  14.29171111 15.59151429
#  14.3651907  17.65297643 14.40187406 20.         16.98010444 14.21808085
#  17.98415334 18.31186061 14.21808085 18.63612537 14.25491483 14.29171111
#  14.40187406 14.62118609 14.32846972 17.98415334 15.94408725 13.39813781
#  14.1442997  14.54823202 14.18120915 20.         14.5116988  14.18120915
#  19.89929615 19.89929615 19.89929615 18.31186061 14.47512809 19.58853338
#  20.         14.87534851 13.77312236 17.65297643 20.         20.
#  18.95697457 13.77312236 14.1442997  14.5116988  14.58472777 14.29171111
#  14.5116988  14.5116988  14.43851985 14.43851985 14.21808085 13.39813781
#  20.         20.         18.63612537 14.47512809 14.25491483 20.
#  14.18120915 20.         14.43851985 14.5116988  16.98010444 14.87534851
#  14.40187406 14.25491483 14.62118609 14.18120915 15.94408725 19.58853338
#  17.31830261 15.94408725 16.98010444 16.98010444]

# %% [markdown]
# حال می‌خواهیم از بین نمرات جدید، آن‌هایی را که بیشتر یا مساوی هفده شده‌اند، در آرایه زیر ذخیره کنیم:

# %%
top_grades = grades[grades>=17]
print(top_grades)
# Out:
# [19.58853338 20.         17.31830261 19.58853338 20.         20.
#  17.31830261 18.95697457 18.63612537 17.65297643 20.         17.98415334
#  18.31186061 18.63612537 17.98415334 20.         19.89929615 19.89929615
#  19.89929615 18.31186061 19.58853338 20.         17.65297643 20.
#  20.         18.95697457 20.         20.         18.63612537 20.
#  20.         19.58853338 17.31830261]

# %% [markdown]
# حال، پنج درایه اول این آرایه را به عنوان نمونه در آرایه زیر می‌ریزیم:

# %%
five_samples =

# %% [markdown]
# با اجرای دستور زیر آرایه‌ها را ذخیره کنید تا پاسخ‌های‌تان مورد ارزیابی قرار گیرند:

# %%
np.savez("answers.npz",grades = grades,top_grades = top_grades,five_samples = five_samples)
